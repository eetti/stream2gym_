# %%
import pandas as pd
import numpy as np

# %%
schedule = pd.read_csv('./schedule.csv', index_col=0)
ct = schedule['producer->compression_type'].to_list()
options = ['None', 'gzip', 'snappy', 'lz4']
for i, item in enumerate(ct):
    ct[i] = options.index(ct[i])
schedule['producer->compression_type'] = ct

# %%
states = pd.read_csv('states.csv', index_col=0).sort_values(by=['run_index'])
states = states.loc[:, (states != states.iloc[0]).any()]
states = states[~states.index.duplicated(keep='last')]

# %%
schedule
# Out:
#        producer->batch_size  producer->linger_ms  producer->buffer_memory  \
# index
# 0                    169550                   59                  8862781
# 1                    194027                   18                 12456982
# 2                    141063                   76                  7031483
# 3                     95794                   30                 25065833
# 4                    212093                   99                  9119279
# ...                     ...                  ...                      ...
# 4995                 144458                   27                  5307122
# 4996                   2126                   32                   454174
# 4997                 182683                   36                 23625202
# 4998                  10734                   88                 30600801
# 4999                  24894                   32                  6982257
#
#        producer->compression_type  producer->topics  \
# index
# 0                               3                 9
# 1                               1                 2
# 2                               3                 7
# 3                               1                 1
# 4                               2                 1
# ...                           ...               ...
# 4995                            1                 3
# 4996                            1                 3
# 4997                            2                10
# 4998                            1                 7
# 4999                            1                 9
#
#        broker->num.network.threads  broker->num.io.threads  \
# index
# 0                                3                       2
# 1                                9                       5
# 2                               16                      14
# 3                               13                      13
# 4                                4                      15
# ...                            ...                     ...
# 4995                             4                       6
# 4996                             8                      23
# 4997                            14                      21
# 4998                            11                      15
# 4999                            13                       9
#
#        broker->queued.max.requests  consumer->fetch_wait_max_ms
# index
# 0                              159                          327
# 1                              425                          118
# 2                              135                          226
# 3                              281                          358
# 4                              292                          355
# ...                            ...                          ...
# 4995                           491                          405
# 4996                           413                          279
# 4997                           422                          283
# 4998                            71                          372
# 4999                            30                          444
#
# [5000 rows x 9 columns]

# %%
states
# Out:
#            Latency  Throughput  gc_collection_count  gc_collection_time  \
# run_index
# 0             2.82        0.03                  8.0               108.0
# 1             2.52        0.73                  8.3               162.2
# 2             3.03        0.03                  7.6               105.0
# 3             2.83        0.03                  8.3               104.6
# 4             2.06        0.03                  6.4                96.8
# ...            ...         ...                  ...                 ...
# 209           1.13        0.05                  8.2               106.4
# 210           1.19        0.05                  7.9                98.9
# 211           2.22        0.96                  8.2               102.8
# 212           3.39        0.03                  7.6               112.8
# 213           3.14        0.04                  8.2               110.5
#
#            jvm_loaded_class_count  jvm_total_loaded_class_count  \
# run_index
# 0                         7028.45                        7152.4
# 1                         7018.24                        7139.1
# 2                         7004.73                        7145.5
# 3                         7008.50                        7149.0
# 4                         6985.78                        7119.3
# ...                           ...                           ...
# 209                       7008.38                        7125.6
# 210                       7023.26                        7146.8
# 211                       7009.16                        7128.2
# 212                       7008.13                        7130.1
# 213                       7017.18                        7135.0
#
#            last_gc_info_duration  memory_heap_usage_used  \
# run_index
# 0                          14.37            2.007207e+08
# 1                          12.26            2.035758e+08
# 2                          13.76            1.950866e+08
# 3                          16.36            1.925519e+08
# 4                          22.80            1.889849e+08
# ...                          ...                     ...
# 209                        16.88            1.918644e+08
# 210                        16.73            1.948707e+08
# 211                        14.72            2.034614e+08
# 212                        17.37            1.900044e+08
# 213                        16.46            1.953426e+08
#
#            memory_non_heap_usage_used  \
# run_index
# 0                         63204205.79
# 1                         63101826.40
# 2                         62849525.74
# 3                         63119155.88
# 4                         62201499.45
# ...                               ...
# 209                       63477168.55
# 210                       63395583.67
# 211                       63289776.10
# 212                       63061666.93
# 213                       63193278.19
#
#            network_request_FetchConsumer_ResponseSendTimeMs  ...  \
# run_index                                                    ...
# 0                                                  122154.5  ...
# 1                                                  132114.5  ...
# 2                                                  125300.0  ...
# 3                                                  119979.5  ...
# 4                                                  139645.0  ...
# ...                                                     ...  ...
# 209                                                122779.0  ...
# 210                                                124539.5  ...
# 211                                                139670.0  ...
# 212                                                121965.0  ...
# 213                                                120750.5  ...
#
#            os_process_cpu_load  os_process_cpu_time  os_system_cpu_load  \
# run_index
# 0                         0.01         2.133400e+10                0.59
# 1                         0.01         2.269000e+10                0.64
# 2                         0.01         2.118700e+10                0.57
# 3                         0.01         2.163400e+10                0.61
# 4                         0.01         1.779200e+10                0.53
# ...                        ...                  ...                 ...
# 209                       0.01         2.246300e+10                0.62
# 210                       0.01         2.195700e+10                0.59
# 211                       0.01         2.261500e+10                0.62
# 212                       0.01         2.166000e+10                0.60
# 213                       0.01         2.176700e+10                0.62
#
#            server_broker_topics_AllTopicsBytesIn  \
# run_index
# 0                                        5797.56
# 1                                        6416.00
# 2                                        5521.57
# 3                                        5832.94
# 4                                        5692.55
# ...                                          ...
# 209                                     19712.15
# 210                                     17894.04
# 211                                      8561.85
# 212                                      5001.53
# 213                                      6376.09
#
#            server_broker_topics_AllTopicsBytesOut  \
# run_index
# 0                                       297250.26
# 1                                       314065.01
# 2                                       252087.58
# 3                                       291831.20
# 4                                       510629.92
# ...                                           ...
# 209                                     900197.06
# 210                                     903834.45
# 211                                     383418.11
# 212                                     222697.50
# 213                                     285859.11
#
#            server_broker_topics_AllTopicsMessagesIn  \
# run_index
# 0                                             17.33
# 1                                             19.42
# 2                                             19.71
# 3                                             17.71
# 4                                             18.82
# ...                                             ...
# 209                                           20.12
# 210                                           18.82
# 211                                           19.59
# 212                                           20.30
# 213                                           19.29
#
#            server_broker_topics_TotalFetchRequestsPerSec  \
# run_index
# 0                                                 106.29
# 1                                                 126.20
# 2                                                 106.16
# 3                                                 101.50
# 4                                                 114.22
# ...                                                  ...
# 209                                               113.12
# 210                                               119.14
# 211                                               122.04
# 212                                               111.36
# 213                                               104.76
#
#            server_broker_topics_TotalProduceRequestsPerSec  \
# run_index
# 0                                                    11.58
# 1                                                    19.30
# 2                                                    10.02
# 3                                                    17.52
# 4                                                    11.09
# ...                                                    ...
# 209                                                  20.01
# 210                                                   9.54
# 211                                                  19.47
# 212                                                  13.57
# 213                                                  19.17
#
#            server_purgatory_NumDelayedFetchRequests  threading_thread_count
# run_index
# 0                                             45.13                   68.64
# 1                                             44.93                   68.50
# 2                                             50.69                   68.42
# 3                                             43.03                   68.61
# 4                                             52.10                   68.12
# ...                                             ...                     ...
# 209                                           46.49                   68.53
# 210                                           47.03                   68.46
# 211                                           45.38                   68.54
# 212                                           46.49                   68.63
# 213                                           46.61                   68.60
#
# [214 rows x 27 columns]

# %%
schedule.to_csv('./processed/schedule.csv')
